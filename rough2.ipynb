# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as soup

# %%
header = {'Origin': 'https://www.1mg.com',
        'Referer': 'https://www.1mg.com/categories/diabetes/diabetic-medicines-583?filter=true&uses=Diabetes%20Care',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
        }

# %%
html = requests.get('https://www.1mg.com/categories/diabetes/diabetic-medicines-583?filter=true&uses=Diabetes%20Care', headers=header)
soup_obj = soup(html.content, 'lxml')

# %%
print(soup_obj.prettify())
# Out:
# <!DOCTYPE html>
# <!-- Chrome, Firefox OS, Opera and Vivaldi -->
# <html>
#  <head>
#   <meta content="#FFF3E3" name="theme-color"/>
#   <!-- Windows Phone -->
#   <meta content="#FFF3E3" name="msapplication-navbutton-color"/>
#   <!-- iOS Safari -->
#   <meta content="#FFF3E3" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <!--Newrelic Header-->
#   <!-- Application styles-->
#   <link href="/faviconRebrand.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta content="099F7701BE7D0B79C7C51734FDC2A2D9" name="msvalidate.01"/>
#   <link href="/notifyvisitors_push/chrome/manifest.json" rel="manifest"/>
#   <!-- Apple Touch Icons-->
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# ...

# %%
# med_name = []

# for name in soup_obj.findAll('div', class_ = 'style__pro-title___2QwJy') :
#     med_name.append(name.text.strip())

# %%
# rating = []

# for name in soup_obj.findAll('div', class_ = 'CardRatingDetail__ratings-container___2ZTSK') :
#     if(name.text.strip() == None) :
#         rating.append('0.0')
#     else :
#         rating.append(name.text.strip())

# %%
# len(rating)

# %% [markdown]
# col-md-3 col-sm-4 col-xs-6 style__container___1TL2R

# %%
product_name = []
quantity = []
product_rating = []
product_rating_count = []
product_price = []

for item in soup_obj.findAll('div', class_ = 'col-md-3 col-sm-4 col-xs-6 style__container___1TL2R') :
    
    for p_name in item.findAll('div', class_ = 'style__pro-title___2QwJy') :
        product_name.append(p_name.text.strip())
        
    for p_quan in item.findAll('div', class_ = 'style__pack-size___2JQG7') :
        quantity.append(p_quan.text.strip())
        
    curr_rating = []
    for p_rate in item.findAll('div', class_ = 'CardRatingDetail__ratings-container___2ZTSK') :
        curr_rating.append(p_rate.text.strip())
    if len(curr_rating) > 0 :
        product_rating += curr_rating
    else :
        product_rating.append('0.0')
        
    curr_rating_count = []
    for p_rate_count in item.findAll('span', class_ = 'CardRatingDetail__ratings-header___2yyQW') :
        curr_rating_count.append(p_rate_count.text.strip())
    if len(curr_rating_count) > 0 :
        product_rating_count += curr_rating_count
    else :
        product_rating_count.append('0 ratings')
        
    for p_price in item.findAll('div', class_ = 'style__price-tag___cOxYc') :
        product_price.append(p_price.text.strip())

# %%
temp_price = []
for pp in product_price :
    temp_price.append(pp.split('₹')[1])

temp_rating = []
for rat in product_rating_count :
    temp_rating.append(rat.split(' ')[0])

# %%
diction = {'product' : product_name, 'quantity' : quantity, 
           'rating' : product_rating, 'number of ratings' : temp_rating,
           'price' : temp_price}

# %%
data = pd.DataFrame(diction)
data
# Out:
#                                               product  \
# 0                                       Bgr 34 Tablet
# 1       1mg Karela Pure Natural Extract 500mg Capsule
# 2   Dr. Reckeweg R40 Diabetes Drop Homeopathic Med...
# 3           SBL Syzygium Jambolanum Mother Tincture Q
# 4            Dhootapapeshwar Madhumeha Kusumakar Rasa
# 5                     Sugar Free Green Stevia Pellets
# 6                                    SBL Dibonil Drop
# 7                                        IME 9 Tablet
# 8   Tata 1mg Ceylon Cinnamon 10:1 Ratio Extract fo...
# 9                   So Sweet Stevia Sugar Free Tablet
# 10                              Dabur GlycoDab Tablet
# 11                           Himalaya Diabecon Tablet
# 12            SBL Gymnema Sylvestre Mother Tincture Q
# 13       Dr. Reckeweg Syzygium Jamb Mother Tincture Q
# 14               Baidyanath Mahayograj Guggulu Tablet
# 15                              SBL Diaboherb Capsule
# ...
